# %% [markdown]
# # Pruebas rápidas de la API Green Dream
# Este notebook realiza comprobaciones básicas contra la API desplegada localmente:
# - Verifica el endpoint `/api/health`
# - Envía una petición de ejemplo a `/api/chat` y muestra la respuesta
#
# Usa este notebook para validar que el servicio backend está disponible antes de integrar el chat en una web externa.

# %%
# Instalación mínima (si hace falta) e importaciones
import sys
try:
    import requests
except Exception:
    print("requests no está instalado. Instalando...")
    import subprocess
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'requests'])
    import requests
from pprint import pprint

# %%
# Detectar la URL base adecuada (host.docker.internal cuando se ejecuta desde Docker host)
import requests
from requests.exceptions import RequestException

CANDIDATES = ['http://host.docker.internal:5001', 'http://localhost:5001']

def get_base_url(timeout=1):
    for url in CANDIDATES:
        try:
            r = requests.get(url + '/api/health', timeout=timeout)
            if r.status_code == 200:
                return url
        except RequestException:
            continue
    # Si ninguno responde, devolver el primero para diagnóstico
    return CANDIDATES[-1]

BASE_URL = get_base_url()
print('Usando BASE_URL =', BASE_URL)
# Out:
# Usando BASE_URL = http://localhost:5001

# %%
# Llamar a /api/health y mostrar resultado
try:
    r = requests.get(BASE_URL + '/api/health', timeout=5)
    r.raise_for_status()
    pprint(r.json())
except Exception as e:
    print('Error llamando a /api/health:', e)
# Out:
# {'assistant_initialized': True,
#  'service': 'Green Dream Chat API',
#  'status': 'healthy',
#  'version': '1.0.0'}

# %%
# Ejemplo POST a /api/chat (puede fallar si no hay credenciales de Azure configuradas)
payload = {
    'message': 'Hola, ¿qué cursos recomiendas sobre sostenibilidad?'
}
try:
    r = requests.post(BASE_URL + '/api/chat', json=payload, timeout=20)
    if r.status_code == 200:
        pprint(r.json())
    else:
        print(f'Respuesta inesperada {r.status_code}:', r.text)
except Exception as e:
    print('Error llamando a /api/chat:', e)
# Out:
# {'response': '¡Hola! 🌟 Es genial que quieras aprender más sobre '
#              'sostenibilidad, ya que los jóvenes como tú son clave para '
#              'construir un futuro más verde. Aquí te dejo algunas '
#              'recomendaciones personalizadas y adaptadas a lo que Green Dream '
#              'ofrece:\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### **🎓 Curso: Fundamentos de Sostenibilidad para Jóvenes**  \n'
#              '📋 **Nivel:** Principiante (perfecto si estás empezando a '
#              'explorar este apasionante tema).  \n'
#              '💻 **Modalidad:** Online (puedes hacerlo desde cualquier lugar, '
#              '¡a tu ritmo!).  \n'
#              '💰 **Precio:** **Gratuito** (¡no tienes excusas para no '
#              'comenzar!).  \n'
#              '🔗 **Inscripción y más información:** [Accede aquí al '
#              'curso](https://greendream.org/cursos/fundamentos-sostenibilidad).  \n'
#              '\n'
#              '#### ¿Por qué te recomiendo este curso?  \n'
#              'Este curso es una introducción perfecta para entender los '
#              'conceptos básicos sobre el desarrollo sostenible y los '
#              '**Objetivos de Desarrollo Sostenible (ODS)** de la ONU. Te '
#              'ayudará a conectar con ideas prácticas que puedes aplicar desde '
#              'tu vida cotidiana. 🌱  \n'
#              '\n'
#              'Además, al ser gratuito y online, es súper accesible para que '
#              'puedas iniciarte en el tema sin compromisos. ¡Es una oportunidad '
#              'increíble para comenzar tu viaje por la sostenibilidad!\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### **📚 Complementa tu aprendizaje con estos artículos:**\n'
#              '\n'
#              '#### 🌍 **Artículo: 10 Acciones Sostenibles que Todo Joven Puede '
#              'Implementar Hoy**  \n'
#              '🔗 **URL:** [Léelo '
#              'aquí](https://greendream.org/articulos/10-acciones-sostenibles-jovenes)  \n'
#              '📝 **Resumen:** Una guía súper práctica que te ayudará a poner en '
#              'práctica pequeñas acciones sostenibles en tu día a día. Desde '
#              'ahorrar energía hasta reducir el consumo de plástico, ¡cada '
#              'acción cuenta!  \n'
#              '\n'
#              '*(Tip: Puedes completar lo que aprendas en el curso con estas '
#              'acciones concretas para empezar a generar impacto desde ya.)*\n'
#              '\n'
#              '---\n'
#              '\n'
#              '#### 🚀 **Artículo: Tecnologías Verdes: Innovaciones que Están '
#              'Cambiando el Mundo**  \n'
#              '🔗 **URL:** [Descúbrelo '
#              'aquí](https://greendream.org/articulos/tecnologias-verdes-innovaciones)  \n'
#              '📝 **Resumen:** Si además te interesa la tecnología y cómo está '
#              'ayudando a transformar el mundo hacia un futuro más sostenible, '
#              'este artículo es un excelente recurso para explorar '
#              'innovaciones.  \n'
#              '\n'
#              '*(Tip: Una vez que tengas una base sólida de sostenibilidad, '
#              'este artículo te inspirará a involucrarte en proyectos '
#              'tecnológicos verdes.)*\n'
#              '\n'
#              '---\n'
#              '\n'
#              '### 🌟 ¿Por dónde empezar?  \n'
#              '1. Inscríbete en el curso gratuito: [Fundamentos de '
#              'Sostenibilidad para '
#              'Jóvenes](https://greendream.org/cursos/fundamentos-sostenibilidad).  \n'
#              '2. Lee el artículo **10 Acciones Sostenibles** para empezar a '
#              'aplicar lo que aprendas en tu vida diaria.  \n'
#              '3. Explora el artículo sobre **Tecnologías Verdes** si quieres '
#              'llevar tu aprendizaje al siguiente nivel.\n'
#              '\n'
#              '💬 Si tienes dudas o quieres más recomendaciones, ¡házmelo saber! '
#              'Estoy aquí para acompañarte en tu camino hacia un impacto '
#              'positivo en el mundo. 🌱 ¡Vamos a construir juntos un futuro más '
#              'sostenible! 💚',
#  'source': 'Green Dream RAG Assistant',
#  'success': True}

# %% [markdown]
# ## Notas
# - Si `/api/chat` devuelve error 500 es probable que falten las credenciales de Azure (AZURE_AI_ENDPOINT / AZURE_AI_KEY).
# - Copia `config/.env.example` a `config/.env` y rellena las variables antes de ejecutar en tu máquina:
#
# ```powershell
# Copy-Item .\config\.env.example .\config\.env
# notepad .\config\.env
# # Rellenar AZURE_AI_ENDPOINT y AZURE_AI_KEY
# ```
#
# - En entornos de producción usa mecanismos de secretos gestionados (Azure KeyVault, Docker secrets, etc.).
