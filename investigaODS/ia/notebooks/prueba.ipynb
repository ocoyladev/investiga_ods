# %% [markdown]
# # Pruebas

# %%
# para hacer prueba en chrome
# https://web-production-d5451.up.railway.app/api/health
# En la consola de Chrome, puedes usar el siguiente código:
fetch("https://web-production-d5451.up.railway.app/api/chat", {
  method: "POST",
  headers: { "Content-Type": "application/json" },
  body: JSON.stringify({ message: "Hola desde Chrome — ¿estás activo?" })
})
.then(resp => resp.json())
.then(data => console.log("Respuesta API:", data))
.catch(err => console.error("Error:", err));
